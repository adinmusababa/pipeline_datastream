# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

db = client["clustering_datastreaming"]

collection = db["clusters"]

data = list(collection.find())

# %%
df = pd.DataFrame(data)
df
# Out:
#                             _id  \
# 0      690f3f3b9548306210519b14
# 1      690f3f3b9548306210519b15
# 2      690f3f3b9548306210519b16
# 3      690f3f3b9548306210519b17
# 4      690f3f3b9548306210519b18
# ...                         ...
# 61995  690f44a39548306210529cd5
# 61996  690f44a39548306210529cd6
# 61997  690f44a39548306210529cd7
# 61998  690f44a39548306210529cd8
# 61999  690f44a39548306210529cd9
#
#                                                 features  \
# 0      [0.14666466151600754, 1.4954300133397767, -1.1...
# 1      [0.14666466151600754, -0.6414390542646898, -1....
# 2      [0.14666466151600754, -0.2914935768041515, -1....
# 3      [0.14666466151600754, -0.5884831968776335, -1....
# 4      [0.14666466151600754, 1.080271917019778, -1.13...
# ...                                                  ...
# 61995  [0.7962628978020778, 0.40209193568795154, 1.22...
# 61996  [0.7962628978020778, 1.3782550087725787, 1.229...
# 61997  [0.7962628978020778, 0.40209193568795154, 1.22...
# 61998  [0.7962628978020778, 1.5777769548627545, 1.229...
# 61999  [0.7962628978020778, 1.3782550087725787, 1.229...
#
#                                                 raw_data  cluster_id  \
# 0      {'User ID': 0, 'Item ID': 1, 'Category ID': -1...           0
# 1      {'User ID': 0, 'Item ID': 0, 'Category ID': -1...           1
# 2      {'User ID': 0, 'Item ID': 0, 'Category ID': -1...           1
# 3      {'User ID': 0, 'Item ID': 0, 'Category ID': -1...           1
# 4      {'User ID': 0, 'Item ID': 1, 'Category ID': -1...           0
# ...                                                  ...         ...
# 61995  {'User ID': 0, 'Item ID': 0, 'Category ID': 1,...          22
# 61996  {'User ID': 0, 'Item ID': 1, 'Category ID': 1,...          22
# 61997  {'User ID': 0, 'Item ID': 0, 'Category ID': 1,...          22
# 61998  {'User ID': 0, 'Item ID': 1, 'Category ID': 1,...           5
# 61999  {'User ID': 0, 'Item ID': 1, 'Category ID': 1,...          22
#
#       true_label               timestamp  User ID  Item ID  Category ID  \
# 0           None 2025-11-08 13:01:47.356        0        1           -1
# 1           None 2025-11-08 13:01:47.360        0        0           -1
# 2           None 2025-11-08 13:01:47.363        0        0           -1
# 3           None 2025-11-08 13:01:47.368        0        0           -1
# 4           None 2025-11-08 13:01:47.371        0        1           -1
# ...          ...                     ...      ...      ...          ...
# 61995       None 2025-11-08 13:24:51.759        0        0            1
# 61996       None 2025-11-08 13:24:51.777        0        1            1
# 61997       None 2025-11-08 13:24:51.801        0        0            1
# 61998       None 2025-11-08 13:24:51.825        0        1            1
# 61999       None 2025-11-08 13:24:51.862        0        1            1
#
#       Behavior type               original_id  processing_counter last_updated
# 0                pv  6821f62d18a8dab949d03672                   1          NaT
# 1                pv  6821f62d18a8dab949d03673                   2          NaT
# 2                pv  6821f62d18a8dab949d03674                   3          NaT
# 3                pv  6821f62d18a8dab949d03675                   4          NaT
# 4                pv  6821f62d18a8dab949d03676                   5          NaT
# ...             ...                       ...                 ...          ...
# 61995            pv  6821f62e18a8dab949d1289d               61996          NaT
# 61996            pv  6821f62e18a8dab949d1289e               61997          NaT
# 61997            pv  6821f62e18a8dab949d1289f               61998          NaT
# 61998            pv  6821f62e18a8dab949d128a0               61999          NaT
# 61999            pv  6821f62e18a8dab949d128a1               62000          NaT
#
# [62000 rows x 13 columns]

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
